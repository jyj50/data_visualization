# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
import platform

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
df_대전 = pd.read_csv(r'C:\Users\i7 8700K\Desktop\data_visualization\dataset\대전8월기온.csv', encoding='euc-kr', skiprows=7, sep=",")
df_세종 = pd.read_csv(r'C:\Users\i7 8700K\Desktop\data_visualization\dataset\세종8월기온.csv', encoding='euc-kr', skiprows=7, sep=",")
df_서울 = pd.read_csv(r'C:\Users\i7 8700K\Desktop\data_visualization\dataset\서울8월기온.csv', encoding='euc-kr', skiprows=7, sep=",")

# %%
df_대전.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       31 non-null     datetime64[ns]
#  1   지점       31 non-null     int64
#  2   평균기온(℃)  31 non-null     float64
#  3   최저기온(℃)  31 non-null     float64
#  4   최고기온(℃)  31 non-null     float64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 1.3 KB

# %%
df_대전["날짜"] = pd.to_datetime(df_대전["날짜"])
df_세종["날짜"] = pd.to_datetime(df_세종["날짜"])
df_서울["날짜"] = pd.to_datetime(df_서울["날짜"])

# %%
plt.figure(figsize=(14,6))

# 각 지점 선 그래프
plt.plot(df_서울["날짜"], df_서울["평균기온(℃)"], marker="o", linestyle="-", label="서울", color="r")
plt.plot(df_대전["날짜"], df_대전["평균기온(℃)"], marker="o", linestyle="-", label="대전", color="g")
plt.plot(df_세종["날짜"], df_세종["평균기온(℃)"], marker="o", linestyle="-", label="세종", color="b")

# 그래프 꾸미기
plt.title("서울, 대전, 세종 평균 기온 변화 추이", fontsize=16)
plt.xlabel("날짜", fontsize=12)
plt.ylabel("평균 기온 (°C)", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.5)
plt.legend()

plt.show()
